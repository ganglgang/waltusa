# %%
import pandas as pd

# %%
data = pd.read_csv('7_26_8_2_product.csv')

# %%
data.head(5)
# Out:
#                    DateRec                       PlantCode  \
# 0  2020-07-29 12:37:41.000  USA
# 1  2020-07-29 12:40:05.000  USA
# 2  2020-07-29 12:47:35.000  USA
# 3  2020-07-29 12:49:49.000  USA
# 4  2020-07-29 12:49:57.000  USA
#
#                          RoomCode                       GroupCode  MachCode  \
# 0  KNITTING-ROOM                   LINE-1                                 9
# 1  KNITTING-ROOM                   LINE-1                                 8
# 2  KNITTING-ROOM                   LINE-1                                15
# 3  KNITTING-ROOM                   LINE-1                                14
# 4  KNITTING-ROOM                   LINE-1                                21
#
#                   OrderCode                 StyleCode            StSize  \
# 0                            CQ0301        03
# 1                            CQ0301        03
# 2                            CQ0301        02
# 3                            CQ0301        03
# ...

# %%
data.columns.values
# Out:
# array(['DateRec', 'PlantCode', 'RoomCode', 'GroupCode', 'MachCode',
#        'OrderCode', 'StyleCode', 'StSize', 'StColor', 'StLot', 'TimeOn',
#        'TimeOff', 'Pieces', 'OrderPieces', 'TargetPieces', 'Discards',
#        'Cycle', 'Condition', 'Shift', 'RespoCode', 'Reason',
#        'OrderDiscards', 'DateStartShift', 'BalancingCode', 'LinkProgram',
#        'NameProg1', 'TargetProg1', 'PiecesProg1', 'CycleTimeProg1',
#        'NameProg2', 'TargetProg2', 'PiecesProg2', 'CycleTimeProg2',
#        'NameProg3', 'TargetProg3', 'PiecesProg3', 'CycleTimeProg3',
#        'NameProg4', 'TargetProg4', 'PiecesProg4', 'CycleTimeProg4',
#        'NameProg5', 'TargetProg5', 'PiecesProg5', 'CycleTimeProg5',
#        'MachineId', 'ShiftDisabled', 'ManualStopInProd', 'ModelCode'],
#       dtype=object)

# %%
data = data[['DateRec','MachCode','StyleCode','TimeOn', 'TimeOff','Pieces','Discards','Cycle']]

# %%
data.head()
# Out:
#                    DateRec  MachCode                 StyleCode  TimeOn  \
# 0  2020-07-29 12:37:41.000         9  CQ0301        03            1502
# 1  2020-07-29 12:40:05.000         8  CQ0301        03            1119
# 2  2020-07-29 12:47:35.000        15  CQ0301        02           14262
# 3  2020-07-29 12:49:49.000        14  CQ0301        03            1801
# 4  2020-07-29 12:49:57.000        21  s5277-4b      02            8684
#
#    TimeOff  Pieces  Discards  Cycle
# 0      159       5         1    298
# 1      337       4         1    297
# 2      730      53         2    261
# 3     1930       6         1    298
# 4     3373      43         1    201

# %%
data
# Out:
#                       DateRec  MachCode                 StyleCode  TimeOn  \
# 0     2020-07-29 12:37:41.000         9  CQ0301        03            1502
# 1     2020-07-29 12:40:05.000         8  CQ0301        03            1119
# 2     2020-07-29 12:47:35.000        15  CQ0301        02           14262
# 3     2020-07-29 12:49:49.000        14  CQ0301        03            1801
# 4     2020-07-29 12:49:57.000        21  s5277-4b      02            8684
# ...                       ...       ...                       ...     ...
# 1543  2020-08-02 19:00:00.000        11  BK09X007      02               0
# 1544  2020-08-02 19:00:00.000        28  PCAGHI        01               0
# 1545  2020-08-02 19:00:00.000        30  ZK2361        01               0
# 1546  2020-08-02 19:00:00.000        33  CQ0301        03               0
# 1547  2020-08-02 19:00:00.000        22  s5277-4b      02               0
#
#       TimeOff  Pieces  Discards
# 0         159       5         1
# ...

# %%
data.head()
# Out:
#                    DateRec  MachCode                 StyleCode  TimeOn  \
# 0  2020-07-29 12:37:41.000         9  CQ0301        03            1502
# 1  2020-07-29 12:40:05.000         8  CQ0301        03            1119
# 2  2020-07-29 12:47:35.000        15  CQ0301        02           14262
# 3  2020-07-29 12:49:49.000        14  CQ0301        03            1801
# 4  2020-07-29 12:49:57.000        21  s5277-4b      02            8684
#
#    TimeOff  Pieces  Discards
# 0      159       5         1
# 1      337       4         1
# 2      730      53         2
# 3     1930       6         1
# 4     3373      43         1

# %%
data_1 = data[data['MachCode']==1]

# %%
data_1.head(100)
# Out:
#                       DateRec  MachCode                 StyleCode  TimeOn  \
# 39    2020-07-29 16:25:51.000         1  CQ0301        03           17167
# 45    2020-07-29 17:02:37.000         1  CQ0301        03            1794
# 55    2020-07-29 17:54:21.000         1  CQ0301        03            2530
# 58    2020-07-26 07:00:00.000         1  CQ0301        03            1491
# 72    2020-07-26 07:18:16.000         1  CQ0301        03             606
# ...                       ...       ...                       ...     ...
# 1396  2020-08-02 03:20:54.000         1  CQ0301        03            1304
# 1398  2020-08-02 03:35:07.000         1  CQ0301        03             825
# 1403  2020-08-02 04:18:58.000         1  CQ0301        03            2096
# 1421  2020-08-02 06:27:31.000         1  CQ0301        03            6101
# 1428  2020-08-02 07:00:00.000         1  CQ0301        03            1102
#
#       TimeOff  Pieces  Discards  Cycle
# 39        584      57         1    297
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2020-08-02'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-303455d09b76> in <module>
# ----> 1 print(data_9['2020-08-02'])
#
# ...

# %%
t1=datetime(2020,8,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-9cd4fdd483c7> in <module>
# ----> 1 t1=datetime(2020,8,2)
#
# NameError: name 'datetime' is not defined

# %%
data_9['DateRec']=pd.to_datetime(data_9['DateRec'])
# Out:
# C:\Users\gangl\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_9
# Out:
#                  DateRec  MachCode                 StyleCode  TimeOn  TimeOff  \
# 0    2020-07-29 12:37:41         9  CQ0301        03            1502      159
# 8    2020-07-29 13:10:51         9  CQ0301        03            1655      335
# 44   2020-07-29 16:58:15         9  CQ0301        03           13353      291
# 48   2020-07-29 17:27:00         9  CQ0301        03            1496      229
# 54   2020-07-29 17:53:31         9  CQ0301        03            1297      294
# ...                  ...       ...                       ...     ...      ...
# 1440 2020-08-02 07:00:00         9  CQ0301        03            6500      229
# 1482 2020-08-02 12:05:00         9  CQ0301        03           16728     1572
# 1490 2020-08-02 15:27:10         9  CQ0301        03           11026     1104
# 1491 2020-08-02 16:04:04         9  CQ0301        03            1293      921
# 1523 2020-08-02 19:00:00         9  CQ0301        03           10206      350
#
#       Pieces  Discards
# ...

# %%
data_9.head(20)
# Out:
#                      DateRec  MachCode                 StyleCode  TimeOn  \
# 0    2020-07-29 12:37:41.000         9  CQ0301        03            1502
# 8    2020-07-29 13:10:51.000         9  CQ0301        03            1655
# 44   2020-07-29 16:58:15.000         9  CQ0301        03           13353
# 48   2020-07-29 17:27:00.000         9  CQ0301        03            1496
# 54   2020-07-29 17:53:31.000         9  CQ0301        03            1297
# 70   2020-07-26 07:00:00.000         9  CQ0301        03           31372
# 73   2020-07-26 07:20:14.000         9  CQ0301        03             603
# 109  2020-07-26 12:29:24.000         9  CQ0301        03           16100
# 114  2020-07-26 13:17:06.000         9  CQ0301        03            2483
# 116  2020-07-26 13:30:30.000         9  CQ0301        03             711
# 119  2020-07-26 13:53:58.000         9  CQ0301        03             977
# 125  2020-07-26 15:10:49.000         9  CQ0301        03            3945
# ...

# %%
1+54+9+1+3+13+9+18+14
# Out:
# 122

# %%
12*60*60/298
# Out:
# 144.96644295302013

# %%
122/144
# Out:
# 0.8472222222222222
